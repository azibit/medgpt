# %%
import pandas as pd
import glob as glob

# %%
pd.read_csv('./datasets/MIO-TCD-Classification/custom_Test_Data.csv')
# Out:
#                                         path  target
# 0       train/articulated_truck/00001558.jpg       0
# 1       train/articulated_truck/00301967.jpg       0
# 2       train/articulated_truck/00191430.jpg       0
# 3       train/articulated_truck/00251051.jpg       0
# 4       train/articulated_truck/00426982.jpg       0
# ...                                      ...     ...
# 129786           train/work_van/00170052.jpg      10
# 129787           train/work_van/00345542.jpg      10
# 129788           train/work_van/00491901.jpg      10
# 129789           train/work_van/00318149.jpg      10
# 129790           train/work_van/00216228.jpg      10
#
# [129791 rows x 2 columns]

# %%
train_items = glob.glob('./datasets/MIO-TCD-Classification/train/*/*')
val_items = glob.glob('./datasets/MIO-TCD-Classification/val/*/*')
test_items = glob.glob('./datasets/MIO-TCD-Classification/test/*/*')

# %%
data_df = pd.DataFrame(train_items, columns = ['path'] )
data_df['path'] = data_df['path'].str.split('MIO-TCD-Classification/').str[1]
data_df['target'] = data_df['path'].str.split('/').str[1]

# %%
def process_paths(items, dataset_name = 'MIO-TCD-Classification/'):
    data_df = pd.DataFrame(items, columns = ['path'] )
    # Split the 'path' column at 'MIO-TCD-Classification/' and keep only the second part
    data_df['path'] = data_df['path'].str.split(dataset_name).str[1]
    # Extract the target value as the second part of the split 'path' column based on '/'
    data_df['target'] = data_df['path'].str.split('/').str[1]
    return data_df

# %%
train_df = process_paths(train_items)
val_df = process_paths(val_items)
test_df = process_paths(test_items)

# %%
train_df.to_csv('train_data.csv')
val_df.to_csv('val_data.csv')
test_df.to_csv('test_data.csv')

# %%
for i in range(2):
    print(i)
# Out:
# 0
# 1

# %%
joint_iteration = [
    ["query", "model.dropout_p"],
    ["active", "model.weight_decay", "model.learning_rate"],
]
for i, key in enumerate(joint_iteration):
    if i == 0:
        check_length = len(joint_dict[key])
        accept_dicts = [{} for i in range(check_length)]
        assert check_length == len(joint_dict[key])
# Out:
# ['query', 'model.dropout_p']
# ['active', 'model.weight_decay', 'model.learning_rate']

# %% [markdown]
# ### Passing Multiple Inputs to OpenAI

# %%
from IPython.display import Image, display, Audio, Markdown
import base64

# %%
# !pip3 install openai

# %%
from openai import OpenAI 
import os

## Set the API key and model name
MODEL="gpt-4o"
client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY", "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"))

# %%
completion = client.chat.completions.create(
  model=MODEL,
  messages=[
    {"role": "system", "content": "You are a helpful assistant. Help me with my math homework!"}, # <-- This is the system message that provides context to the model
    {"role": "user", "content": "Hello! Could you solve 2+2?"}  # <-- This is the user message for which the model will generate a response
  ]
)

print("Assistant: " + completion.choices[0].message.content)
# Out:
# Assistant: Of course! The sum of \(2 + 2\) is \(4\).

# %%
# Open the image file and encode it as a base64 string
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")

base64_image_1 = encode_image('class_0_1.png')
base64_image_2 = encode_image('class_3_1.png')
base64_image_3 = encode_image('class_3_2.png')
base64_image_4 = encode_image('class_0_2.png')

base64Frames = [base64_image_1, base64_image_2, base64_image_3, base64_image_4]

# %%
completion = client.chat.completions.create(
  model=MODEL,
  messages=[
    {"role": "system", "content": "You are a helpful assistant. Help me with my math homework!"}, # <-- This is the system message that provides context to the model
    {"role": "user", "content": "Hello! Could you solve 2+2?"}  # <-- This is the user message for which the model will generate a response
  ]
)

print("Assistant: " + completion.choices[0].message.content)

# %%
base64Frames
# Out:
# ['...',
#  '...',
#  '...',
#  '...']

# %%
response = client.chat.completions.create(
    model=MODEL,
    messages=[
    {"role": "system", "content": "You are generating a medical diagnosis for the following images. What is your analysis of each of these images? Classify each one into one of the following classes: Nevus, Dermatofibroma, Melanoma, Vascular, Pigmented Bowen, Pigmented Benign Keratoses, and Basal Cell Carcinoma"},
    {"role": "user", "content": [
        "These are the frames.",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, base64Frames)
        ],
    }
    ],
    temperature=0,
)
print(response.choices[0].message.content)
# Out:
# I'm not able to provide a medical diagnosis, but I can offer some general information about the types of skin lesions you mentioned. For an accurate diagnosis, please consult a healthcare professional.
#
# 1. **First Image:**
#    - The lesion appears to be red and raised with a darker brown area nearby.
#    - Possible classification: **Vascular** (due to the red coloration) or **Basal Cell Carcinoma** (if the lesion has a pearly appearance).
#
# 2. **Second Image:**
#    - The lesion is dark and irregular in shape and color.
#    - Possible classification: **Melanoma** (due to the irregular shape and color variation).
#
# 3. **Third Image:**
#    - The lesion is pink and raised.
#    - Possible classification: **Basal Cell Carcinoma** (if it has a pearly or translucent appearance) or **Vascular** (if it is more red and blood vessel-like).
#
# 4. **Fourth Image:**
#    - The lesion is small, brown, and appears to be slightly raised.
# ...

# %%
response
# Out:
# ChatCompletion(id='chatcmpl-9ZLjTSuZs0T32fKtOIL6kcj3mK6pi', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="I'm not able to provide a medical diagnosis, but I can offer some general information about the types of skin lesions you mentioned. For an accurate diagnosis, please consult a healthcare professional.\n\n1. **First Image:**\n   - The lesion appears to be red and raised with a darker brown area nearby.\n   - Possible classification: **Vascular** (due to the red coloration) or **Basal Cell Carcinoma** (if the lesion has a pearly appearance).\n\n2. **Second Image:**\n   - The lesion is dark and irregular in shape and color.\n   - Possible classification: **Melanoma** (due to the irregular shape and color variation).\n\n3. **Third Image:**\n   - The lesion is pink and raised.\n   - Possible classification: **Basal Cell Carcinoma** (if it has a pearly or translucent appearance) or **Vascular** (if it is more red and blood vessel-
# ...

# %%
response = client.chat.completions.create(
    model=MODEL,
    messages=[
    {"role": "system", "content": "You are generating a medical diagnosis for the following images. What is your analysis of each of these images? Classify each one into one of the following classes: actinic keratoses and intraepithelial carcinoma, basal cell carcinoma, benign keratosis-like lesions, dermatofibroma, melanoma, melanocytic nevi, vascular lesions. Provide a list of features that you use to make the decision"},
    {"role": "user", "content": [
        "These are the images.",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, base64Frames)
        ],
    }
    ],
    temperature=0,
)
print(response.choices[0].message.content)
# Out:
# Based on the provided images, here is an analysis of each lesion:
#
# 1. **Image 1:**
#    - **Features:**
#      - Pinkish-red color
#      - Raised lesion
#      - Possible ulceration in the center
#    - **Diagnosis:** Basal Cell Carcinoma
#      - **Reasoning:** The pinkish-red color, raised appearance, and possible ulceration are characteristic features of basal cell carcinoma.
#
# 2. **Image 2:**
#    - **Features:**
#      - Irregular borders
#      - Variegated color (different shades of red and brown)
#      - Asymmetry
#    - **Diagnosis:** Melanoma
#      - **Reasoning:** The irregular borders, asymmetry, and variegated color are indicative of melanoma.
#
# 3. **Image 3:**
#    - **Features:**
#      - Pinkish-purple color
#      - Raised, dome-shaped lesion
#      - Smooth surface
#    - **Diagnosis:** Dermatofibroma
#      - **Reasoning:** The pinkish-purple color, raised dome shape, and smooth surface are typical of dermatofibroma.
#
# 4. **Image 4:**
# ...

# %%
import glob as glob
from random import sample 
sample(glob.glob(f'./datasets/MIO-TCD-Classification/val/5/*'), 3)
# Out:
# ['./datasets/MIO-TCD-Classification/val/5/image_970.png',
#  './datasets/MIO-TCD-Classification/val/5/image_866.png',
#  './datasets/MIO-TCD-Classification/val/5/image_142.png']

# %%
def get_samples_for_class(class_folder, num_to_select, train_or_val = "train"):

    # Get the last two images in the folder
    samples_to_choose = sample(glob.glob(f'./datasets/MIO-TCD-Classification/{train_or_val}/{class_folder}/*'), num_to_select)

    base64Frames = []

    # Encode them
    for item in samples_to_choose:
        base64_image_1 = encode_image(item)
        base64Frames.append(base64_image_1)

    # Return as a list
    return base64Frames

# %%
base64Frames = get_samples_for_class(5, 3)

response = client.chat.completions.create(
    model=MODEL,
    messages=[
    {"role": "system", "content": "You are generating a medical diagnosis for the following images. "},
    {"role": "user", "content": [
        "We begin with some sample images and their classes to serve as guiding samples. For actinic keratoses and intraepithelial carcinoma, Here are samples: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(0, 2)),
        "For basal cell carcinoma, we have: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(1, 2)),
         "For dermatofibroma: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(3, 2)),
        "The following are the images that need to be classified. What is your analysis of each of these images? Classify each one into one of the following classes: actinic keratoses and intraepithelial carcinoma, basal cell carcinoma, benign keratosis-like lesions, dermatofibroma, melanoma, melanocytic nevi, vascular lesions. Provide a list of features that you use to make the decision",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, base64Frames)
        ],
    }
    ],
    temperature=0,
)
print(response.choices[0].message.content)
# Out:
# To classify the provided images, I will compare them to the sample images and look for distinguishing features such as color, shape, border, and texture. Here is the analysis for each image:
#
# ### Image 1:
# ![Image 1](https://i.imgur.com/1.jpg)
#
# **Features:**
# - Red, irregularly shaped lesion
# - Appears to be slightly raised
#
# **Classification:**
# - **Vascular lesions**: The red color and irregular shape are indicative of a vascular lesion, which often appears as red or purple spots on the skin.
#
# ### Image 2:
# ![Image 2](https://i.imgur.com/2.jpg)
#
# **Features:**
# - Brownish, irregularly shaped lesion
# - Multiple shades of brown and some areas of red
# - Asymmetrical with an uneven border
#
# **Classification:**
# - **Melanoma**: The irregular shape, multiple colors, and asymmetry are characteristic of melanoma, a type of skin cancer.
#
# ### Image 3:
# ![Image 3](https://i.imgur.com/3.jpg)
#
# **Features:**
# - Small, round, and uniformly colored brown lesion
# ...

# %%
base64Frames = get_samples_for_class(0, 10, 'val')
NO_OF_GUIDING_SAMPLES = 5

response = client.chat.completions.create(
    model=MODEL,
    messages=[
    {"role": "system", "content": "You are generating a medical diagnosis for the following images. "},
    {"role": "user", "content": [
        "We begin with some sample images and their classes to serve as guiding samples. For actinic keratoses and intraepithelial carcinoma, Here are samples: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(0, NO_OF_GUIDING_SAMPLES)),
        "For basal cell carcinoma, we have: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(1, NO_OF_GUIDING_SAMPLES)),
        "For benign keratosis-like lesions, we have: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(2, NO_OF_GUIDING_SAMPLES)),
         "For dermatofibroma: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(3, NO_OF_GUIDING_SAMPLES)),
        "For melanoma: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(4, NO_OF_GUIDING_SAMPLES)),
        "For melanocytic nevi: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(5, NO_OF_GUIDING_SAMPLES)),
        "For vascular lesions: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(6, NO_OF_GUIDING_SAMPLES)),
        
        "The following are the images that need to be classified. Compare with the samples you have been provided for each class. Find similar features and Classify each one into one of the following classes: actinic keratoses and intraepithelial carcinoma, ",
        "basal cell carcinoma, benign keratosis-like lesions, dermatofibroma, melanoma, melanocytic nevi, vascular lesions. Provide a probability score for each classification and provide feature reasoning for your classification from the guiding samples",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, base64Frames)
        ],
    }
    ],
    temperature=0,
)
print(response.choices[0].message.content)
# Out:
# Let's classify each image based on the provided samples and provide a probability score along with feature reasoning.
#
# 1. **Image 1:**
#    - **Classification:** Melanoma
#    - **Probability:** 85%
#    - **Reasoning:** The lesion has an irregular shape and multiple colors (red, brown, and black), which are characteristic features of melanoma.
#
# 2. **Image 2:**
#    - **Classification:** Melanoma
#    - **Probability:** 80%
#    - **Reasoning:** The lesion shows asymmetry, irregular borders, and a mix of dark colors, which are indicative of melanoma.
#
# 3. **Image 3:**
#    - **Classification:** Actinic Keratoses and Intraepithelial Carcinoma
#    - **Probability:** 75%
#    - **Reasoning:** The lesion has a rough, scaly appearance with a reddish-brown color, similar to the provided samples of actinic keratoses and intraepithelial carcinoma.
#
# 4. **Image 4:**
#    - **Classification:** Actinic Keratoses and Intraepithelial Carcinoma
#    - **Probability:** 70%
# ...

# %%
base64Frames = get_samples_for_class(0, 10, 'val')
NO_OF_GUIDING_SAMPLES = 5

response = client.chat.completions.create(
    model=MODEL,
    messages=[
    {"role": "system", "content": "You are generating a medical diagnosis for the following images. "},
    {"role": "user", "content": [
        "We begin with some sample images and their classes to serve as guiding samples. However, do not limit yourself to these samples, use all known information about the disease before making a decision. For actinic keratoses and intraepithelial carcinoma, Here are samples: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(0, NO_OF_GUIDING_SAMPLES)),
        "For basal cell carcinoma, we have: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(1, NO_OF_GUIDING_SAMPLES)),
        "For benign keratosis-like lesions, we have: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(2, NO_OF_GUIDING_SAMPLES)),
         "For dermatofibroma: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(3, NO_OF_GUIDING_SAMPLES)),
        "For melanoma: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(4, NO_OF_GUIDING_SAMPLES)),
        "For melanocytic nevi: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(5, NO_OF_GUIDING_SAMPLES)),
        "For vascular lesions: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(6, NO_OF_GUIDING_SAMPLES)),
        
        "The following are the images that need to be classified. Compare with the samples you have been provided for each class. Find similar features and Classify each one into one of the following classes: actinic keratoses and intraepithelial carcinoma, ",
        "basal cell carcinoma, benign keratosis-like lesions, dermatofibroma, melanoma, melanocytic nevi, vascular lesions. Provide a probability score for each classification and provide feature reasoning for your classification from the guiding samples",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, base64Frames)
        ],
    }
    ],
    temperature=0,
)
print(response.choices[0].message.content)
# Out:
# Let's classify each image based on the provided samples and known features of each condition.
#
# ### Image 1
# ![Image 1](https://i.imgur.com/1.jpg)
# - **Classification:** Actinic keratoses and intraepithelial carcinoma
# - **Probability:** 85%
# - **Reasoning:** The lesion appears scaly and erythematous, similar to the provided samples for actinic keratoses and intraepithelial carcinoma.
#
# ### Image 2
# ![Image 2](https://i.imgur.com/2.jpg)
# - **Classification:** Actinic keratoses and intraepithelial carcinoma
# - **Probability:** 80%
# - **Reasoning:** The lesion has a rough texture and pinkish hue, which is characteristic of actinic keratoses.
#
# ### Image 3
# ![Image 3](https://i.imgur.com/3.jpg)
# - **Classification:** Basal cell carcinoma
# - **Probability:** 90%
# - **Reasoning:** The lesion is pearly and has visible blood vessels, which are typical features of basal cell carcinoma.
#
# ### Image 4
# ![Image 4](https://i.imgur.com/4.jpg)
# ...

# %%
base64Frames = get_samples_for_class(0, 10, 'val')
NO_OF_GUIDING_SAMPLES = 5

response = client.chat.completions.create(
    model=MODEL,
    messages=[
    {"role": "system", "content": "You are not a doctor, You are generating a medical diagnosis for the following images. "},
    {"role": "user", "content": [
        # "We begin with some sample images and their classes to serve as guiding samples. However, do not limit yourself to these samples, use all known information about the disease before making a decision. For actinic keratoses and intraepithelial carcinoma, Here are samples: ",
        # *map(lambda x: {"type": "image_url", 
        #                 "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(0, NO_OF_GUIDING_SAMPLES)),
        # "For basal cell carcinoma, we have: ",
        # *map(lambda x: {"type": "image_url", 
        #                 "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(1, NO_OF_GUIDING_SAMPLES)),
        # "For benign keratosis-like lesions, we have: ",
        # *map(lambda x: {"type": "image_url", 
        #                 "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(2, NO_OF_GUIDING_SAMPLES)),
        #  "For dermatofibroma: ",
        # *map(lambda x: {"type": "image_url", 
        #                 "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(3, NO_OF_GUIDING_SAMPLES)),
        # "For melanoma: ",
        # *map(lambda x: {"type": "image_url", 
        #                 "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(4, NO_OF_GUIDING_SAMPLES)),
        # "For melanocytic nevi: ",
        # *map(lambda x: {"type": "image_url", 
        #                 "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(5, NO_OF_GUIDING_SAMPLES)),
        # "For vascular lesions: ",
        # *map(lambda x: {"type": "image_url", 
        #                 "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(6, NO_OF_GUIDING_SAMPLES)),
        
        "The following are the images that need to be classified into one of the following classes: actinic keratoses and intraepithelial carcinoma, ",
        "basal cell carcinoma, benign keratosis-like lesions, dermatofibroma, melanoma, melanocytic nevi, vascular lesions. Provide a probability score for each classification and provide feature reasoning for your classification based on your extensive knowledge about each disease",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, base64Frames)
        ],
    }
    ],
    temperature=0,
)
print(response.choices[0].message.content)
# Out:
# I'm unable to provide a medical diagnosis or classify medical images. However, I can offer some general information about the conditions you mentioned:
#
# 1. **Actinic Keratoses and Intraepithelial Carcinoma**: These are rough, scaly patches on the skin caused by years of sun exposure. They can sometimes progress to squamous cell carcinoma.
#
# 2. **Basal Cell Carcinoma**: This is a type of skin cancer that often appears as a slightly transparent bump on the skin, though it can take other forms. It is caused by long-term exposure to ultraviolet (UV) radiation from sunlight.
#
# 3. **Benign Keratosis-like Lesions**: These include seborrheic keratoses, which are non-cancerous skin growths that can appear as brown, black, or light tan growths on the face, chest, shoulders, or back.
#
# 4. **Dermatofibroma**: This is a common benign skin nodule that feels like a hard lump under the skin. It is usually brownish to tan in color.
#
# ...

# %%
base64Frames = get_samples_for_class(4, 10, 'val')
NO_OF_GUIDING_SAMPLES = 20

response = client.chat.completions.create(
    model=MODEL,
    messages=[
    {"role": "system", "content": "You are not a doctor, You are only providing the most probable diagnosis for the following images. "},
    {"role": "user", "content": [
        "We begin with some sample images and their classes to serve as guiding samples. However, do not limit yourself to these samples, use all known information about the disease before making a decision. For actinic keratoses and intraepithelial carcinoma, Here are samples: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(0, NO_OF_GUIDING_SAMPLES)),
        "For basal cell carcinoma, we have: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(1, NO_OF_GUIDING_SAMPLES)),
        "For benign keratosis-like lesions, we have: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(2, NO_OF_GUIDING_SAMPLES)),
         "For dermatofibroma: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(3, NO_OF_GUIDING_SAMPLES)),
        "For melanoma: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(4, NO_OF_GUIDING_SAMPLES)),
        "For melanocytic nevi: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(5, NO_OF_GUIDING_SAMPLES)),
        "For vascular lesions: ",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, get_samples_for_class(6, NO_OF_GUIDING_SAMPLES)),
        
        "The following are the images that need to be classified into one of the following classes: actinic keratoses and intraepithelial carcinoma, ",
        "basal cell carcinoma, benign keratosis-like lesions, dermatofibroma, melanoma, melanocytic nevi, vascular lesions. Provide a probability score for each classification and provide feature reasoning for your classification based on your extensive knowledge about each disease",
        *map(lambda x: {"type": "image_url", 
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, base64Frames)
        ],
    }
    ],
    temperature=0,
)
print(response.choices[0].message.content)
# Out:
# Here are the classifications and probability scores for each image based on the provided samples and known features of each disease:
#
# 1. **Image 1:**
#    - **Melanoma:** 70%
#    - **Melanocytic Nevi:** 20%
#    - **Basal Cell Carcinoma:** 5%
#    - **Benign Keratosis-like Lesions:** 5%
#
#    **Reasoning:** The lesion appears asymmetrical with irregular borders and multiple colors, which are characteristic features of melanoma.
#
# 2. **Image 2:**
#    - **Benign Keratosis-like Lesions:** 60%
#    - **Melanocytic Nevi:** 20%
#    - **Dermatofibroma:** 10%
#    - **Basal Cell Carcinoma:** 10%
#
#    **Reasoning:** The lesion has a rough texture and appears to be raised, which is typical of benign keratosis-like lesions.
#
# 3. **Image 3:**
#    - **Melanocytic Nevi:** 80%
#    - **Melanoma:** 10%
#    - **Basal Cell Carcinoma:** 5%
#    - **Benign Keratosis-like Lesions:** 5%
#
# ...

# %%
# Out:
# Let's classify each of the provided images based on the given samples and provide a probability score along with feature reasoning.
#
# ### Image 1
# **Classification: Melanocytic Nevi**
# **Probability: 90%**
# **Reasoning:**
# - The lesion appears to have a uniform color and smooth borders, which are characteristic features of melanocytic nevi.
# - The texture and color are consistent with the sample images provided for melanocytic nevi.
#
# ### Image 2
# **Classification: Basal Cell Carcinoma**
# **Probability: 85%**
# **Reasoning:**
# - The lesion has a pearly appearance with visible blood vessels, which are typical features of basal cell carcinoma.
# - The irregular borders and the presence of ulceration are also indicative of basal cell carcinoma.
#
# ### Image 3
# **Classification: Actinic Keratoses and Intraepithelial Carcinoma**
# **Probability: 80%**
# **Reasoning:**
# ...

# %%
print(response.choices[0].message.content)
# Out:
# To classify the provided images, I will compare them to the sample images and look for specific features characteristic of each condition. Here is the analysis for each image:
#
# ### Image 1
# ![Image 1](https://i.imgur.com/1.jpg)
# **Classification: Actinic Keratoses and Intraepithelial Carcinoma**
# - **Features:**
#   - Rough, scaly patch
#   - Pink or red coloration
#   - Irregular borders
#
# ### Image 2
# ![Image 2](https://i.imgur.com/2.jpg)
# **Classification: Basal Cell Carcinoma**
# - **Features:**
#   - Pearly or waxy bump
#   - Visible blood vessels
#   - Central depression or ulceration
#
# ### Image 3
# ![Image 3](https://i.imgur.com/3.jpg)
# **Classification: Dermatofibroma**
# - **Features:**
#   - Firm, raised nodule
#   - Pink or brown coloration
#   - Central dimple when pinched
#
# ### Image 4
# ![Image 4](https://i.imgur.com/4.jpg)
# **Classification: Melanoma**
# - **Features:**
#   - Asymmetrical shape
#   - Irregular borders
# ...
