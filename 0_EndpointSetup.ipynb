# %% [markdown]
# ### Setup the endpoints

# %%
# !pip3 install anthropic

# %%
import base64
import httpx
import anthropic

# %% [markdown]
# ### Setting up for Anthropic

# %%
client = anthropic.Anthropic(api_key='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')

# %%
# Open the image file and encode it as a base64 string
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")

# %%
image1_url = "https://upload.wikimedia.org/wikipedia/commons/a/a7/Camponotus_flavomarginatus_ant.jpg"
image1_media_type = "image/png"
image1_data = base64.b64encode(httpx.get(image1_url).content).decode("utf-8")
image1_data = encode_image('class_0_1.png')

image2_url = "https://upload.wikimedia.org/wikipedia/commons/b/b5/Iridescent.green.sweat.bee1.jpg"
image2_media_type = "image/png"
image2_data = base64.b64encode(httpx.get(image2_url).content).decode("utf-8")
image2_data = encode_image('class_3_1.png')

# %%
imaged1_data = encode_image('d1.jpeg')
imaged2_data = encode_image('d2.jpeg')
imaged3_data = encode_image('d3.jpeg')
imaged4_data = encode_image('d4.jpeg')

# %%
imagec1_data = encode_image('cat1.jpeg')
imagec2_data = encode_image('cat2.jpeg')
imagec3_data = encode_image('cat3.jpeg')
imagec4_data = encode_image('cat4.jpeg')
image_media_type = "image/jpeg"
imaged_media_type = "image/png"

# %%
message = client.messages.create(
    model="claude-3-5-sonnet-20240620",
    max_tokens=1024,
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "Image 1:"
                },
                {
                    "type": "image",
                    "source": {
                        "type": "base64",
                        "media_type": image_media_type,
                        "data": imaged1_data,
                    },
                },
                {
                    "type": "text",
                    "text": "Image 2:"
                },
                {
                    "type": "image",
                    "source": {
                        "type": "base64",
                        "media_type": image_media_type,
                        "data": imaged4_data,
                    },
                },
                {
                    "type": "text",
                    "text": "What are the commonalities among these images?"
                }
            ],
        }
    ],
)

# %%
print(message.content)
# Out:
# [TextBlock(text="Both images appear to show close-up views of skin with a circular rash or lesion, but there are some notable differences between them:\n\nImage 1:\n- The skin tone appears lighter or more pale\n- The rash has a more diffuse, blotchy appearance\n- There's a reddish-pink coloration spread over a larger area\n- The texture seems smoother overall\n- The edges of the affected area are less defined\n\nImage 2:\n- The skin tone appears slightly darker or more tan\n- The rash is more concentrated and circular in shape\n- It has a more intense reddish-purple coloration in the center\n- There's a more distinct border between the affected area and surrounding skin\n- The texture appears slightly rougher or more raised, especially in the center\n\nThe second image shows a more clearly defined circular lesion with a more intense coloration, while the first image depicts a more spread out, less defined rash or irritation. These differences could potentially indicate different skin
# ...

# %%
message = client.messages.create(
    model="claude-3-5-sonnet-20240620",
    max_tokens=1024,
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "Image 1:"
                },
                {
                    "type": "image",
                    "source": {
                        "type": "base64",
                        "media_type": image1_media_type,
                        "data": image1_data,
                    },
                },
                {
                    "type": "text",
                    "text": "Image 2:"
                },
                {
                    "type": "image",
                    "source": {
                        "type": "base64",
                        "media_type": image2_media_type,
                        "data": image2_data,
                    },
                },
                {
                    "type": "text",
                    "text": "How are these images same?"
                }
            ],
        }
    ],
)

# %%
print(message.content)
# Out:
# [TextBlock(text="These two images appear to be close-up photographs of skin with similar reddish, inflamed appearances. Both show what looks like irritated or affected skin with a pinkish-red coloration.\n\nThe texture in both images is somewhat bumpy or uneven, suggesting some kind of skin condition or reaction. The coloration is not uniform, with some areas appearing more intensely red or pink than others.\n\nWhile I can't diagnose specific conditions, these images could potentially represent various skin issues such as rashes, allergic reactions, or other dermatological conditions. The similar coloration and texture between the two images suggest they may be depicting the same or a similar skin condition, just potentially at different stages or on different areas of the body.\n\nWithout more context, it's difficult to determine if these are images of the exact same area over time or different areas with a similar condition. However, the overall visual similarities in color, textur
# ...

# %%
message = client.messages.create(
    model="claude-3-5-sonnet-20240620",
    max_tokens=1024,
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "Image 1:"
                },
                {
                    "type": "image",
                    "source": {
                        "type": "base64",
                        "media_type": image_media_type,
                        "data": imaged1_data,
                    },
                },
                {
                    "type": "text",
                    "text": "Image 2:"
                },
                {
                    "type": "image",
                    "source": {
                        "type": "base64",
                        "media_type": image_media_type,
                        "data": imaged4_data,
                    },
                },
                {
                    "type": "text",
                    "text": "What are the commonalities among these images?"
                }
            ],
        }
    ],
)
print(message.content[0].text)
# Out:
# [TextBlock(text='Both images feature dogs with very expressive, happy facial expressions. Here are the key commonalities:\n\n1. Joyful expressions: Both dogs have wide, open mouths that give the appearance of big smiles, indicating they\'re in a playful or excited mood.\n\n2. Visible teeth: You can see the dogs\' teeth in both images, contributing to their enthusiastic expressions.\n\n3. Tongues out: Both dogs have their tongues visible, which is often associated with a happy, panting dog.\n\n4. Close-up shots: The images are close-ups of the dogs\' faces, allowing for a clear view of their features and expressions.\n\n5. Alert ears: Both dogs have their ears perked up or slightly raised, suggesting they\'re attentive and engaged.\n\n6. Bright eyes: The eyes of both dogs appear bright and alert, adding to their overall lively appearance.\n\n7. Different breeds: While the dogs are different breeds (the first appears to be a Shetland Sheepdog or similar breed, and the second looks like
# ...

# %%
print(message.content[0].text)
# Out:
# Both images feature dogs with very expressive, happy facial expressions. Here are the key commonalities:
#
# 1. Joyful expressions: Both dogs have wide, open mouths that give the appearance of big smiles, indicating they're in a playful or excited mood.
#
# 2. Visible teeth: You can see the dogs' teeth in both images, contributing to their enthusiastic expressions.
#
# 3. Tongues out: Both dogs have their tongues visible, which is often associated with a happy, panting dog.
#
# 4. Close-up shots: The images are close-ups of the dogs' faces, allowing for a clear view of their features and expressions.
#
# 5. Alert ears: Both dogs have their ears perked up or slightly raised, suggesting they're attentive and engaged.
#
# 6. Bright eyes: The eyes of both dogs appear bright and alert, adding to their overall lively appearance.
#
# ...

# %%
message = client.messages.create(
    model="claude-3-5-sonnet-20240620",
    max_tokens=1024,
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "Image 1:"
                },
                {
                    "type": "image",
                    "source": {
                        "type": "base64",
                        "media_type": image_media_type,
                        "data": imaged1_data,
                    },
                },
                {
                    "type": "text",
                    "text": "Image 2:"
                },
                {
                    "type": "image",
                    "source": {
                        "type": "base64",
                        "media_type": image_media_type,
                        "data": imaged4_data,
                    },
                },
                {
                    "type": "text",
                    "text": "What are the commonalities among these images?"
                }
            ],
        }
    ],
)
print(message.content[0].text)
# Out:
# Both images show dogs with very happy, excited expressions:
#
# 1. The first image shows a smiling dog with reddish-brown and white fur, likely a breed like a Shetland Sheepdog or small Collie mix. Its mouth is wide open in a big grin, showing its teeth and tongue. The dog's ears are perked up and its eyes are bright and alert.
#
# 2. The second image depicts a different dog, possibly a Jack Russell Terrier or similar breed, with a black, white and tan coat. This dog also has its mouth open wide with its tongue hanging out in a joyful expression. Its eyes are wide and attentive.
#
# The commonalities between these images include:
#
# 1. Both dogs appear extremely happy and excited.
# 2. They both have their mouths open wide, showing their teeth and tongues.
# 3. Their eyes are bright and alert, conveying enthusiasm.
# 4. Both images are close-up shots focusing on the dogs' faces.
# 5. The dogs' ears are visible and somewhat perked up or alert.
# ...

# %%
message = client.messages.create(
    model="claude-3-5-sonnet-20240620",
    max_tokens=1024,
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "Image 1:"
                },
                {
                    "type": "image",
                    "source": {
                        "type": "base64",
                        "media_type": image_media_type,
                        "data": imaged1_data,
                    },
                },
                {
                    "type": "text",
                    "text": "Image 2:"
                },
                {
                    "type": "image",
                    "source": {
                        "type": "base64",
                        "media_type": image_media_type,
                        "data": imaged4_data,
                    },
                },
                {
                    "type": "text",
                    "text": "What are the differences between images 1 and 2?"
                }
            ],
        }
    ],
)
print(message.content[0].text)
# Out:
# There are several notable differences between the two images:
#
# 1. Breed: Image 1 shows what appears to be a Shetland Sheepdog or Sheltie, while Image 2 depicts a dog that looks like a Jack Russell Terrier or similar mixed breed.
#
# 2. Coloration: The dog in Image 1 has a predominantly reddish-brown and white coat, while the dog in Image 2 has a tricolor coat of black, white, and tan.
#
# 3. Expression: The dog in Image 1 has a wide, open-mouthed smile giving it an excited, happy appearance. The dog in Image 2 also appears happy but with its tongue sticking out to the side, giving it a slightly goofy or playful look.
#
# 4. Background: Image 1 has a plain white background, while Image 2 shows an outdoor setting with a wooden structure (possibly a fence or shed) and some greenery visible.
#
# 5. Ear position: The dog in Image 1 has its ears perked up and forward, while the dog in Image 2 has one ear up and one ear flopped down.
#
# ...

# %%
message = client.messages.create(
    model="claude-3-5-sonnet-20240620",
    max_tokens=1024,
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "Image 1:"
                },
                {
                    "type": "image",
                    "source": {
                        "type": "base64",
                        "media_type": image_media_type,
                        "data": imaged1_data,
                    },
                },
                {
                    "type": "text",
                    "text": "Image 2:"
                },
                {
                    "type": "image",
                    "source": {
                        "type": "base64",
                        "media_type": image_media_type,
                        "data": imaged4_data,
                    },
                },
                {
                    "type": "text",
                    "text": "What are the differences between images 1 and 2 in terms of their breeds?"
                }
            ],
        }
    ],
)
print(message.content[0].text)
# Out:
# The two images show different dog breeds with distinct characteristics:
#
# Image 1 features a dog that appears to be a Shetland Sheepdog (Sheltie) or a similar herding breed mix. It has a fox-like face, erect ears, and a thick, fluffy coat that's reddish-brown and white. The dog has a very happy, wide-mouthed smile showing its enthusiasm.
#
# Image 2 shows a dog that looks like a Jack Russell Terrier or a similar terrier mix. This dog has a shorter coat with black, white, and tan coloring in a typical terrier pattern. It has a longer snout, floppy ears, and is also shown with its mouth open and tongue out in a playful expression.
#
# Key differences:
# 1. Coat length and texture: Image 1 has a long, fluffy coat while Image 2 has a short, smooth coat.
# 2. Coloration: Image 1 is primarily reddish-brown and white, while Image 2 is black, white, and tan.
# 3. Ear shape: Image 1 has pointed, erect ears, while Image 2 has floppy ears.
# ...

# %%
message = client.messages.create(
    model="claude-3-5-sonnet-20240620",
    max_tokens=1024,
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "Image 1:"
                },
                {
                    "type": "image",
                    "source": {
                        "type": "base64",
                        "media_type": image_media_type,
                        "data": imaged1_data,
                    },
                },
                {
                    "type": "text",
                    "text": "Image 2:"
                },
                {
                    "type": "image",
                    "source": {
                        "type": "base64",
                        "media_type": image_media_type,
                        "data": imagec1_data,
                    },
                },
                {
                    "type": "text",
                    "text": "What are the differences between images 1 and 2?"
                }
            ],
        }
    ],
)
print(message.content[0].text)
# Out:
# The two images show very different animals with distinct characteristics:
#
# Image 1:
# - Features a dog, specifically what appears to be a Shetland Sheepdog or similar breed
# - The dog has a brown and white coat
# - It's showing a wide, open-mouthed smile, appearing very happy and excited
# - The dog's ears are perked up and forward
# - The image is focused on the dog's face and upper body
# - The background is plain white
#
# Image 2:
# - Shows a kitten, likely a white or light-colored breed
# - The kitten has blue eyes and pink ears
# - It appears to be young, with a curious expression
# - The kitten is sitting, with its body partially visible
# - It's positioned on what looks like a leopard print fabric or cushion
# - The background is dark, creating contrast with the light-colored kitten
#
# Key differences:
# 1. Species: Dog vs. Cat
# 2. Age: Adult dog vs. Young kitten
# 3. Expression: Excited, smiling dog vs. Curious, alert kitten
# ...

# %%
message = client.messages.create(
    model="claude-3-5-sonnet-20240620",
    max_tokens=1024,
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "Image 1:"
                },
                {
                    "type": "image",
                    "source": {
                        "type": "base64",
                        "media_type": image_media_type,
                        "data": imaged1_data,
                    },
                },
                {
                    "type": "text",
                    "text": "Image 2:"
                },
                {
                    "type": "image",
                    "source": {
                        "type": "base64",
                        "media_type": image_media_type,
                        "data": imagec1_data,
                    },
                },
                {
                    "type": "text",
                    "text": "What are the similarities between images 1 and 2?"
                }
            ],
        }
    ],
)
print(message.content[0].text)
# Out:
# While these images feature different animals, there are several similarities between them:
#
# 1. Both show pets: Image 1 is a dog, and Image 2 is a kitten.
#
# 2. Facial focus: Both images primarily showcase the animals' faces.
#
# 3. Expressive features: Both animals have prominent, engaging eyes that draw the viewer's attention.
#
# 4. Light coloration: The dog has light brown and white fur, while the kitten is predominantly white.
#
# 5. Upward gaze: Both animals are looking slightly upward, giving them an alert and attentive appearance.
#
# 6. Close-up shots: The images are taken as close-ups, allowing for detailed views of the animals' features.
#
# 7. Positive emotion: The dog appears to be smiling with its mouth open, while the kitten looks curious and sweet, both evoking positive feelings.
#
# 8. Studio-style backgrounds: Both images appear to be taken in controlled settings with plain backgrounds, highlighting the animals themselves.
#
# ...

# %%
message = client.messages.create(
    model="claude-3-5-sonnet-20240620",
    max_tokens=1024,
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "Image 1:"
                },
                {
                    "type": "image",
                    "source": {
                        "type": "base64",
                        "media_type": image_media_type,
                        "data": imaged1_data,
                    },
                },
                {
                    "type": "text",
                    "text": "Image 2:"
                },
                {
                    "type": "image",
                    "source": {
                        "type": "base64",
                        "media_type": image_media_type,
                        "data": imagec1_data,
                    },
                },
                {
                    "type": "text",
                    "text": "What are the similarities between images 1 and 2?"
                }
            ],
        }
    ],
)
print(message.content[0].text)
